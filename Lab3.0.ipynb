# %%
import pandas as panda
from deeppavlov import configs, build_model

# %%
data = panda.read_csv('C:/Users/maksi/anaconda3/dataset/toxic_comments.csv')
text = data['text']

# %%
model = build_model('insults_kaggle_bert', download = True)
# Out:
# 2023-11-22 17:10:04.218 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/datasets/insults_data.tar.gz download because of matching hashes
# 2023-11-22 17:10:07.37 INFO in 'deeppavlov.download'['download'] at line 138: Skipped http://files.deeppavlov.ai/deeppavlov_data/classifiers/insults_kaggle_torch_bert_v5.tar.gz download because of matching hashes
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# ...

# %%
for i in range(1, 51, 1):
    print("Твит №", i, ", тональность текста :", model([text[i]]))
    print(text[i])
    print("----------------------------------------------------------------------------------------------------")
# Out:
# Твит № 1 , тональность текста : ['Not Insult']
# D'aww! He matches this background colour I'm seemingly stuck with. Thanks.  (talk) 21:51, January 11, 2016 (UTC)
# ----------------------------------------------------------------------------------------------------
# Твит № 2 , тональность текста : ['Not Insult']
# Hey man, I'm really not trying to edit war. It's just that this guy is constantly removing relevant information and talking to me through edits instead of my talk page. He seems to care more about the formatting than the actual info.
# ----------------------------------------------------------------------------------------------------
# Твит № 3 , тональность текста : ['Not Insult']
# "
# More
# ...
